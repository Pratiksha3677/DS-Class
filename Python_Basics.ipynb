# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratiksha3677/DS-Class/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Pratiksha")
# Out:
# Hello Pratiksha

# %%
x=200
print(x)
# Out:
# 200

# %%
y=10.10
print(y)
# Out:
# 10.1

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
x=1
y=1
print(id(x))
print(id(y))


a=20
b=10
print(id(a))
print(id(b))
# Out:
# 11654664

# %%
a = 15
print(type(a))

f = 1.234
print(type(f))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-862957590.py in <cell line: 0>()
#       1 a = 15
# ----> 2 print(type(a))
#       3
#       4 f = 1.234
#       5 print(type(f))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'type'

# %%
a=1+2j
a
# Out:
# (1+2j)

# %%
a=10+1.5j
b=20+2.5j
c=a+b
c
# Out:
# (30+4j)

# %%
True + True
# Out:
# 2

# %%
True+False
# Out:
# 1

# %%
False-False
# Out:
# 0
