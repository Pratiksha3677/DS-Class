# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratiksha3677/DS-Class/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Pratiksha")
# Out:
# Hello Pratiksha

# %%
x=200
print(x)
# Out:
# 200

# %%
y=10.10
print(type(y))
# Out:
# <class 'float'>

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
x=1
y=1
print(id(x))
print(id(y))


a=20
b=10
print(id(a))
print(id(b))
# Out:
# 11654664

# %%
f = 1.234
print(type(f))
# Out:
# <class 'float'>

# %%
a=1+2j
a
# Out:
# (1+2j)

# %%
a=10+1.5j
b=20+2.5j
c=a+b
c
# Out:
# (30+4j)

# %%
True + True
# Out:
# 2

# %%
True+False
# Out:
# 1

# %%
False-False
# Out:
# 0

# %%
list=[10,"pratiksha",1.9,True,10]
list.append(10)
print(list)
# Out:
# [10, 'pratiksha', 1.9, True, 10, 10]

# %%
x=(10,20,30,40)
b=bytes(x)
type(b)
# Out:
# bytes

# %%
x=(10,20,30,40,50)
b=bytearray(x)
b[0]=100
print(b)
# Out:
# bytearray(b'd\x14\x1e(2')

# %%
x=(10,20,30,40,50)    #bytearray eg
b=bytearray(x)
b[0]=100
print(b)
# Out:
# bytearray(b'd\x14\x1e(2')

# %%
t=(1,2,3,4,5)    #tuple eg
print(type(t))
# Out:
# <class 'tuple'>

# %%
a1= "python"     #slicing of string eg
print(a1[-3])


a1='pratiksha'
print(a1[:4])

a2='shrisha'
print(a2[3:])


a3="my world"
print(a3[:])
# Out:
# h
# prat
# isha
# my world

# %%
d={101:'Apple',102:'Bannana',103:'Cherry'}   #dic eg
d[104]='mango'
print(d)
# Out:
# {101: 'Apple', 102: 'Bannana', 103: 'Cherry', 104: 'mango'}

# %%
d['a']='Apple'
d['b']='bannana'
print(d)
# Out:
# {101: 'Apple', 102: 'Bannana', 103: 'Cherry', 104: 'mango', 'a': 'Apple', 'b': 'bannana'}

# %%
s={100,0,10,200,10,'Data Science'}
s.add(60)
s.add('Array')
print(s)
# Out:
# {0, 100, 'Array', 200, 'Data Science', 10, 60}

# %% [markdown]
# #Arithmatic oprators

# %%
a=20
b=10
print('a+b=',a+b)
print('a-b=',a-b)
print('a*b=',a*b)
print('a/b=',a/b)
print('a//b=',a//b)
print('a%b=',a%b)
print('a**b=',a**b)
# Out:
# a+b= 30
# a-b= 10
# a*b= 200
# a/b= 2.0
# a//b= 2
# a%b= 0
# a**b= 10240000000000

# %% [markdown]
# Relational operators

# %%
a=20
b=10
print("a<b=",a<b)
print('a>b=',a>b)
print('a<=b=',a<=b)
print('a>=b=',a>=b)

print('a==b',a==b)     #equality opratores
print('a!=b',a!=b)
# Out:
# a<b= False
# a>b= True
# a<=b= False
# a>=b= True
# a==b False
# a!=b True

# %% [markdown]
# Logical oprators

# %%
a=10                         #zero means true /so true value return
b=0
print('a and b =',a and b)

a=40                          #if a is false the automatic returns b value
b=20
print('a and b =',a and b)
# Out:
# a and b = 0
# a and b = 20

# %%
a=1                         # 1 IS TRUE VALUE SO RETURN A VALUE
b= 2
print('a or b =',a or b)

a=0                         # if a is false then retun b value
b=2
print('a or b =',a or b)

print(not 1) # False
not 0 # Tru
# Out:
# a or b = 1
# a or b = 2
# False
# True

# %% [markdown]
# Assignment operators

# %%
x=10
x+=20
print(x)

y=50
y-=20
print(y)

a=2
a*=2
print(a)
# Out:
# 30
# 30
# 4

# %% [markdown]
# slicing of string

# %%
a="python"
print(a[-3])

x="welcome"
print(x[-1])
print(type(x[2]))
# Out:
# h
# e
# <class 'str'>
